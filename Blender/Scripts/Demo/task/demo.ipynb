# %%
import os
import sys
sys.path.append("..")
from Lib.RenderScene import RenderScene
from Lib.ConfigClass import Config

# %% [markdown]
# waiting for about six and a half minutes after running the following cell...
#
# or just ignore the following cell, display the result directly.

# %%
config = Config()
config.width = 400
config.height = 300

# data_path = os.path.dirname(os.getcwd()) + '/../data/'
# config.texture_path = texture_path = data_path + 'texture/checkerboard_blue.png'

# path = os.getcwd()
# path = os.path.dirname(path)
# path = os.path.dirname(path)
# output_path = path + "\Output\image_blue.png"

# config.output_path = output_path

config.mode = "single"
# config.rotation_start = 90
# config.rotation_end = 91
# config.rotation_step = 1

config.plane = "original"

# set material 
config.material = "original"

config.edge_scale = 0.004
config.singularity_scale = 0.020

# config.object_name = "mesh.obj"

# save to json file
config.save_config()

RenderScene = RenderScene()
RenderScene.config = config

RenderScene.render()
# Out:
# start rendering...
# done!

# %% [markdown]
# show the result

# %%
from PIL import Image

path = "../../Output/mesh.png"

display(Image.open(path))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=400x300 at 0x1DBB76A19E8>
