# %%
import os
import sys
sys.path.append("..")
from Lib.Strebel import Strebel
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# original settings

# %%
if __name__ == "__main__":
    colors = ["#FF4081", "blue", "yellow", "orange", "#7C4DFF", "#536DFE", "#880e4f", "#03A9F4", "#8BC34A", "#CDDC39",
              "#FFEB3B", "#795548", "black", "white"]

    strebel = Strebel()
#     strebel.CircleV1()

#     strebel.image_color = "black"
#     strebel.circle_color = "white"
#     strebel.CircleV2()

#     strebel.image_color = "white"
#     strebel.circle_color = "red"
#     strebel.CircleV2()

#     strebel.line_color = colors
#     strebel.LinesXY()
#     strebel.LinesX()
#     strebel.LinesY()

#     strebel.CheckerboardV1()

#     strebel.number = 11
#     strebel.CheckerboardV2()

#     strebel.checkerboard_colors = ["blue", "yellow"]
#     strebel.number = 10
#     strebel.CheckerboardV2()

    # for number in [8, 9, 10, 11]:
#     for color1 in colors:
#         for color2 in colors:
#             if color1 != color2:
#                 # strebel.number = number
#                 strebel.checkerboard_colors = [color1, color2]
#                 strebel.CheckerboardV1()
#                 strebel.image_color = color1
#                 strebel.circle_color = color2
#                 strebel.CircleV2()
#     colors.remove('white')
#     for i in range(20):
#         random.shuffle(colors)
#         strebel.line_color = colors
#         strebel.LinesXY(i)


    colors = ["#FF4081", "blue", "orange", "#7C4DFF", "#536DFE", "#880e4f", "#03A9F4", "#8BC34A", "#795548", "white"]
    for color1 in colors:
        # strebel.number = number
        strebel.image_color = 'white'
        strebel.circle_color = color1
        strebel.CircleV2()
        
        
    colors = ["#FF4081", "blue", "orange", "#7C4DFF", "#536DFE", "#880e4f", "#03A9F4", "#8BC34A", "#795548"]
    for color1 in colors:
        # strebel.number = number
        strebel.image_color = 'white'
        strebel.circle_color = color1
        strebel.CircleV1()

#     for i in range(20):
#         random.shuffle(colors)
#         strebel.line_color = colors
#         strebel.LinesXY(i)

    colors = ["blue", "green", "orange", "brown"]
    count = 0
    for color1 in colors:
        for color2 in colors:
            if color1 != color2:
                strebel.line_color_x = [color1] * 6
                strebel.line_color_y = [color2] * 6
                strebel.LinesXY(count)
                count += 1
    
                
#     strebel.ColormapQuantizedSym()
#     strebel.ColormapQuantized()
#     strebel.ColormapSym()
#     strebel.Colormap()

# %% [markdown]
# display

# %%
f_list = os.listdir(strebel.output_path)
for filename in f_list:
    image = Image.open(strebel.output_path + filename)
    plt.figure()
    plt.imshow(np.asarray(image))
